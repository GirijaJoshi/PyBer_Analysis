# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt
import statistics
import numpy as np

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
average = sum(y_axis)/len(y_axis)
average
# Out:
# 25.182499999999994

# %%
# Get the standard deviation of the values in the y-axis.
stdev = statistics.stdev(y_axis)
stdev
# Out:
# 11.208367917035753

# %%
plt.barh(x_axis,y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# To adjust the major x-axis ticks on a horizontal bar chart, we use the xticks()
plt.barh(x_axis, y_axis)
x_ticks = np.arange(0, 51, step=5.0)
print(x_ticks)
# plt.xticks(np.arange(0, 51, step=5.0))
plt.xticks(x_ticks)
plt.gca().invert_yaxis()
# Out:
# [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]

# %%
# object orianted 
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
x_ticks = np.arange(0, 51, step=5.0)
print(x_ticks)
ax.set_xticks(x_ticks)
plt.show()
# Out:
# [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]

# %%
# object orianted 
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
x_ticks = np.arange(0, 51, step=5.0)
print(x_ticks)
# cal so use set_ticks() with specific axis
ax.xaxis.set_ticks(x_ticks)
plt.show()
# Out:
# [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]

# %%
# object orianted 
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
x_ticks = np.arange(0, 51, step=5.0)
print(x_ticks)
# cal so use set_ticks() with specific axis
ax.xaxis.set_ticks(x_ticks)

# Create minor ticks at an increment of 1.Need to import Multilocator
ax.xaxis.set_minor_locator(MultipleLocator(1))
plt.show()
# Out:
# [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-752ff3847cb3> in <module>
#       8
#       9 # Create minor ticks at an increment of 1.
# ---> 10 ax.xaxis.set_minor_locator(MultipleLocator(1))
#      11 plt.show()
#
# NameError: name 'MultipleLocator' is not defined
